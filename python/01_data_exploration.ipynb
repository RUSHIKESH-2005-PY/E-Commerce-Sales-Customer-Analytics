# %%
df.shape
# Out:
# (120000, 31)

# %%
df.head()
# Out:
#     Order_ID  Order_Date Customer_ID    Customer_Name  \
# 0  ORD900000  2026-02-01  CUST115062  Customer_115062
# 1  ORD900001  2025-10-04  CUST113588  Customer_113588
# 2  ORD900002  2025-02-21  CUST115653  Customer_115653
# 3  ORD900003  2026-02-13  CUST124908  Customer_124908
# 4  ORD900004  2026-08-01  CUST113480  Customer_113480
#
#                Customer_Email  Gender  Age Customer_Signup_Date  \
# 0  customer115062@example.com    Male   18           2022-04-11
# 1  customer113588@example.com    Male   36           2024-11-27
# 2  customer115653@example.com  Female   39           2024-11-13
# 3  customer124908@example.com    Male   26           2023-03-13
# 4  customer113480@example.com  Female   18           2024-07-19
#
#   Acquisition_Channel         State  ...    Profit Order_Status Return_Flag  \
# 0      Organic Search  Chhattisgarh  ...   1662.11      Shipped          No
# 1        Social Media        Punjab  ...  32912.66    Delivered          No
# ...

# %%
df = pd.read_csv("../data/Ecommerce_Sales_Customer_Analytics_Dataset.csv")

# %%
import pandas as pd
